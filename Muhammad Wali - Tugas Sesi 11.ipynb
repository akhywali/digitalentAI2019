# %%
import pandas as pd
import numpy as np
import re

pd.set_option ('display.max_columns', None)

iris = pd.read_csv("iris.csv")

print("Data read into dataframe!")
# Out:
# Data read into dataframe!

# %%
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 9             4.9          3.1           1.5          0.1     Setosa
# 10            5.4          3.7           1.5          0.2     Setosa
# 11            4.8          3.4           1.6          0.2     Setosa
# 12            4.8          3.0           1.4          0.1     Setosa
# ...

# %% [markdown]
# # GANTI NAMA KOLOM

# %%
column_names = iris.columns.values
column_names[0] = "panjang_kelopak"
column_names[1] = "lebar_kelopak"
column_names[2] = "panjang_mahkota"
column_names[3] = "lebar_mahkota"
column_names[4] = "varietas"
iris.columns = column_names

iris.head()
# Out:
#    panjang_kelopak  lebar_kelopak  panjang_mahkota  lebar_mahkota varietas
# 0              5.1            3.5              1.4            0.2   Setosa
# 1              4.9            3.0              1.4            0.2   Setosa
# 2              4.7            3.2              1.3            0.2   Setosa
# 3              4.6            3.1              1.5            0.2   Setosa
# 4              5.0            3.6              1.4            0.2   Setosa

# %% [markdown]
# # MENAMBAHKAN KATA "anggrek"

# %%
iris.columns=column_names
iris["varietas"]="anggrek_"+iris["varietas"].str.lower()
iris.head()
# Out:
#    panjang_kelopak  lebar_kelopak  panjang_mahkota  lebar_mahkota  \
# 0              5.1            3.5              1.4            0.2
# 1              4.9            3.0              1.4            0.2
# 2              4.7            3.2              1.3            0.2
# 3              4.6            3.1              1.5            0.2
# 4              5.0            3.6              1.4            0.2
#
#          varietas
# 0  anggrek_setosa
# 1  anggrek_setosa
# 2  anggrek_setosa
# 3  anggrek_setosa
# 4  anggrek_setosa

# %% [markdown]
# # GANTI SATUAN UKURAN DARI Cm ke Inchi
# Cm to inchi = 0.393701

# %%
iris.iloc[0:,:4] = iris.iloc[0:,:4]*0.393701
iris
# Out:
#      panjang_kelopak  lebar_kelopak  panjang_mahkota  lebar_mahkota  \
# 0           2.007875       1.377954         0.551181       0.078740
# 1           1.929135       1.181103         0.551181       0.078740
# 2           1.850395       1.259843         0.511811       0.078740
# 3           1.811025       1.220473         0.590552       0.078740
# 4           1.968505       1.417324         0.551181       0.078740
# 5           2.125985       1.535434         0.669292       0.157480
# 6           1.811025       1.338583         0.551181       0.118110
# 7           1.968505       1.338583         0.590552       0.078740
# 8           1.732284       1.141733         0.551181       0.078740
# 9           1.929135       1.220473         0.590552       0.039370
# 10          2.125985       1.456694         0.590552       0.078740
# 11          1.889765       1.338583         0.629922       0.078740
# 12          1.889765       1.181103         0.551181       0.039370
# ...
